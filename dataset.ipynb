# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

print("Linhas e colunas:", df.shape)
df.head()
# Out:
# Linhas e colunas: (501, 63)
#    Gender Relationship Status   Age Academic Status  \
# 0    Male              Single  25.0          4 Year
# 1  Female              Single  23.0          3 Year
# 2  Female              Single  22.0          3 Year
# 3    Male              Single  21.0          3 Year
# 4    Male              Single  23.0          3 Year
#
#   Do you work as well as Study?(পড়াশোনার পাশাপাশি চাকরি করেন?)  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Residential Area (আবাসিক এলাকা)  \
# 0                            Hall
# 1                            Hall
# 2                            Hall
# 3                     With family
# 4                            Hall
#
#   Social Economic Status (আর্থ-সামাজিক অবস্থা)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 63 columns):
#  #   Column                                                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                          --------------  -----
#  0   Gender                                                                                                                                                                                                                                          500 non-null    str
# ...

# %%
df["Age"].describe()
# Out:
# count    500.000000
# mean      22.282000
# std        1.646785
# min       18.000000
# 25%       21.000000
# 50%       22.000000
# 75%       23.000000
# max       28.000000
# Name: Age, dtype: float64

# %%
df.isnull().sum()
# Out:
# Gender                                                                                                                                                      1
# Relationship Status                                                                                                                                         1
# Age                                                                                                                                                         1
# Academic Status                                                                                                                                             1
# Do you work as well as Study?(পড়াশোনার পাশাপাশি চাকরি করেন?)                                                                                               1
#                                                                                                                                                            ..
# ...

# %% [markdown]
# # Observou-se que existe aproximadamente 1 valor ausente em praticamente todas as colunas do dataset.

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      357
# Female    143
# Name: count, dtype: int64

# %%
df["Depression Level (BDI-II) (20 items)"].value_counts()
# Out:
# Depression Level (BDI-II) (20 items)
# Minimal Depression     165
# Severe Depression      142
# Moderate Depression    112
# Mild Depression         81
# Name: count, dtype: int64

# %% [markdown]
# # Pré-processamento (Curadoria)

# %%
print("Antes:", df.shape)

df = df.drop_duplicates()

print("Depois:", df.shape)
# Out:
# Antes: (501, 63)
# Depois: (501, 63)

# %%
df = df.dropna()

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Gender                                                                                                                                                          str
# Relationship Status                                                                                                                                             str
# Age                                                                                                                                                         float64
# Academic Status                                                                                                                                                 str
# Do you work as well as Study?(পড়াশোনার পাশাপাশি চাকরি করেন?)                                                                                                   str
#                                                                                                                                                              ...
# ...

# %%
print(df.shape)

df.head()
# Out:
# (500, 63)
#    Gender Relationship Status   Age Academic Status  \
# 0    Male              Single  25.0          4 Year
# 1  Female              Single  23.0          3 Year
# 2  Female              Single  22.0          3 Year
# 3    Male              Single  21.0          3 Year
# 4    Male              Single  23.0          3 Year
#
#   Do you work as well as Study?(পড়াশোনার পাশাপাশি চাকরি করেন?)  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Residential Area (আবাসিক এলাকা)  \
# 0                            Hall
# 1                            Hall
# 2                            Hall
# 3                     With family
# 4                            Hall
#
#   Social Economic Status (আর্থ-সামাজিক অবস্থা)  \
# ...

# %% [markdown]
# # Conclusão
#
# Foram analisados dados relacionados à depressão, solidão e características sociais dos participantes.
#
# Durante o pré-processamento foram realizadas:
#
# - Verificação da estrutura dos dados;
# - Identificação de valores ausentes;
# - Remoção de registros duplicados;
# - Tratamento dos valores nulos.
#
# Após a limpeza, o conjunto de dados ficou preparado para análises estatísticas mais avançadas e possíveis aplicações de aprendizado de máquina.
